# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

## Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline, FeatureUnion


## Metrics
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score


## Models
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor , GradientBoostingRegressor 
from sklearn.neighbors import KNeighborsRegressor

import missingno as msno

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Exploratory Data

# %%
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [5 rows x 35 columns]

# %%
df.sample(5)
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 983    34        No  Travel_Rarely        404  Research & Development
# 1303   47        No  Travel_Rarely       1001  Research & Development
# 788    28        No  Travel_Rarely        857  Research & Development
# 530    27        No  Travel_Rarely        608  Research & Development
# 152    53        No  Travel_Rarely       1436                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 983                  2          4  Technical Degree              1
# 1303                 4          3     Life Sciences              1
# 788                 10          3             Other              1
# 530                  1          2     Life Sciences              1
# 152                  6          2         Marketing              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 983             1383  ...                         4            80
# 1303            1827  ...                         3            80
# 788             1097  ...                         4            80
# 530              725  ...                         4            80
# 152              205  ...                         4            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 983                  0                 14                      2
# 1303                 1                 28                      4
# 788                  0                 10                      4
# 530                  0                  9                      3
# 152                  1                 13                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 983                4              14                 11
# 1303               3              22                 11
# 788                4               8                  7
# 530                3               9                  7
# 152                1               7                  7
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 983                         4                    11
# 1303                       14                    10
# 788                         1                     7
# 530                         0                     7
# 152                         4                     5
#
# [5 rows x 35 columns]

# %%
df.describe().style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_bdfbb_row0_col0, #T_bdfbb_row0_col2, #T_bdfbb_row0_col3, #T_bdfbb_row0_col4, #T_bdfbb_row0_col6, #T_bdfbb_row0_col7, #T_bdfbb_row0_col8, #T_bdfbb_row0_col9, #T_bdfbb_row0_col10, #T_bdfbb_row0_col13, #T_bdfbb_row0_col14, #T_bdfbb_row0_col15, #T_bdfbb_row0_col16, #T_bdfbb_row0_col17, #T_bdfbb_row0_col18, #T_bdfbb_row0_col19, #T_bdfbb_row0_col20, #T_bdfbb_row0_col21, #T_bdfbb_row0_col22, #T_bdfbb_row0_col23, #T_bdfbb_row0_col24, #T_bdfbb_row0_col25, #T_bdfbb_row7_col1, #T_bdfbb_row7_col5, #T_bdfbb_row7_col11, #T_bdfbb_row7_col12 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_bdfbb_row0_col1 {
#   background-color: #71020e;
#   color: #f1f1f1;
# }
# #T_bdfbb_row0_col5 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_bdfbb_row0_col11, #T_bdfbb_row3_col12, #T_bdfbb_row7_col19, #T_bdfbb_row7_col22 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_bdfbb_row0_col12, #T_bdfbb_row1_col3, #T_bdfbb_row1_col4, #T_bdfbb_row1_col6, #T_bdfbb_row1_col8, #T_bdfbb_row1_col9, #T_bdfbb_row1_col10, #T_bdfbb_row1_col13, #T_bdfbb_row1_col15, #T_bdfbb_row1_col16, #T_bdfbb_row1_col18, #T_bdfbb_row1_col20, #T_bdfbb_row1_col21, #T_bdfbb_row1_col23, #T_bdfbb_row1_col24, #T_bdfbb_row1_col25, #T_bdfbb_row2_col0, #T_bdfbb_row2_col3, #T_bdfbb_row2_col4, #T_bdfbb_row2_col6, #T_bdfbb_row2_col7, #T_bdfbb_row2_col8, #T_bdfbb_row2_col9, #T_bdfbb_row2_col10, #T_bdfbb_row2_col
{
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_bdfbb_row1_col2, #T_bdfbb_row1_col19, #T_bdfbb_row1_col22, #T_bdfbb_row2_col2, #T_bdfbb_row2_col19, #T_bdfbb_row2_col22, #T_bdfbb_row3_col0, #T_bdfbb_row3_col7, #T_bdfbb_row3_col14, #T_bdfbb_row4_col14, #T_bdfbb_row4_col19, #T_bdfbb_row5_col2, #T_bdfbb_row5_col14, #T_bdfbb_row5_col19, #T_bdfbb_row6_col22, #T_bdfbb_row6_col23, #T_bdfbb_row6_col25, #T_bdfbb_row7_col13, #T_bdfbb_row7_col20 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_bdfbb_row1_col5, #T_bdfbb_row5_col5 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_bdfbb_row1_col7, #T_bdfbb_row5_col7, #T_bdfbb_row7_col0 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_bdfbb_row1_col11, #T_bdfbb_row2_col5 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_bdfbb_row1_col14, #T_bdfbb_row6_col2, #T_bdfbb_row6_col14, #T_bdfbb_row6_col19, #T_bdfbb_row7_col24, #T_bdfbb_row7_col25 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_bdfbb_row1_col17, #T_bdfbb_row3_col17, #T_bdfbb_row4_col17, #T_bdfbb_row5_col17, #T_bdfbb_row6_col17, #T_bdfbb_row7_col17 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_bdfbb_row2_col1 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_bdfbb_row2_col11 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_bdfbb_row2_col12 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_bdfbb_row4_col0, #T_bdfbb_row7_col14, #T_bdfbb_row7_col23 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_bdfbb_row4_col1 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_bdfbb_row4_col5 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_bdfbb_row4_col11 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_bdfbb_row4_col12 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_bdfbb_row5_col11 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_bdfbb_row6_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_bdfbb_row6_col1 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_bdfbb_row6_col5 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_bdfbb_row6_col7 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_bdfbb_row6_col11 {
#   background-color: #fc8e6e;
#   color: #000000;
# }
# #T_bdfbb_row6_col12 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# #T_bdfbb_row7_col7 {
#   background-color: #ffece3;
#   color: #000000;
# }
# </style>
# <table id="T_bdfbb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdfbb_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_bdfbb_level0_col1" class="col_heading level0 col1" >DailyRate</th>
#       <th id="T_bdfbb_level0_col2" class="col_heading level0 col2" >DistanceFromHome</th>
#       <th id="T_bdfbb_level0_col3" class="col_heading level0 col3" >Education</th>
#       <th id="T_bdfbb_level0_col4" class="col_heading level0 col4" >EmployeeCount</th>
#       <th id="T_bdfbb_level0_col5" class="col_heading level0 col5" >EmployeeNumber</th>
#       <th id="T_bdfbb_level0_col6" class="col_heading level0 col6" >EnvironmentSatisfaction</th>
#       <th id="T_bdfbb_level0_col7" class="col_heading level0 col7" >HourlyRate</th>
#       <th id="T_bdfbb_level0_col8" class="col_heading level0 col8" >JobInvolvement</th>
#       <th id="T_bdfbb_level0_col9" class="col_heading level0 col9" >JobLevel</th>
#       <th id="T_bdfbb_level0_col10" class="col_heading level0 col10" >JobSatisfaction</th>
#       <th id="T_bdfbb_level0_col11" class="col_heading level0 col11" >MonthlyIncome</th>
#       <th id="T_bdfbb_level0_col12" class="col_heading level0 col12" >MonthlyRate</th>
#       <th id="T_bdfbb_level0_col13" class="col_heading level0 col13" >NumCompaniesWorked</th>
#       <th id="T_bdfbb_level0_col14" class="col_heading level0 col14" >PercentSalaryHike</th>
#       <th id="T_bdfbb_level0_col15" class="col_heading level0 col15" >PerformanceRating</th>
#       <th id="T_bdfbb_level0_col16" class="col_heading level0 col16" >RelationshipSatisfaction</th>
#       <th id="T_bdfbb_level0_col17" class="col_heading level0 col17" >StandardHours</th>
#       <th id="T_bdfbb_level0_col18" class="col_heading level0 col18" >StockOptionLevel</th>
#       <th id="T_bdfbb_level0_col19" class="col_heading level0 col19" >TotalWorkingYears</th>
#       <th id="T_bdfbb_level0_col20" class="col_heading level0 col20" >TrainingTimesLastYear</th>
#       <th id="T_bdfbb_level0_col21" class="col_heading level0 col21" >WorkLifeBalance</th>
#       <th id="T_bdfbb_level0_col22" class="col_heading level0 col22" >YearsAtCompany</th>
#       <th id="T_bdfbb_level0_col23" class="col_heading level0 col23" >YearsInCurrentRol

# %%
df.describe(include='O')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df.columns.tolist()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# TotalWorkingYears             40
# TrainingTimesLastYear          7
# WorkLifeBalance                4
# YearsAtCompany                37
# YearsInCurrentRole            19
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
Category = df.select_dtypes(['object']).columns
Numerical = df.select_dtypes(['number']).columns

print("Category Data:")
print("**************")
print(Category,'\n\n')
print("Numerical Data:")
print("**************")
print(Numerical)
# Out:
# Category Data:
# **************
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')
#
#
# Numerical Data:
# **************
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
for i in Category:
    print("unique values of:",i,set(df[i]), "\n")
# Out:
# unique values of: Attrition {'Yes', 'No'}
#
# unique values of: BusinessTravel {'Non-Travel', 'Travel_Frequently', 'Travel_Rarely'}
#
# unique values of: Department {'Sales', 'Research & Development', 'Human Resources'}
#
# unique values of: EducationField {'Other', 'Human Resources', 'Life Sciences', 'Technical Degree', 'Medical', 'Marketing'}
#
# unique values of: Gender {'Female', 'Male'}
#
# unique values of: JobRole {'Manufacturing Director', 'Sales Executive', 'Human Resources', 'Healthcare Representative', 'Research Director', 'Research Scientist', 'Sales Representative', 'Laboratory Technician', 'Manager'}
#
# unique values of: MaritalStatus {'Single', 'Married', 'Divorced'}
#
# unique values of: Over18 {'Y'}
#
# unique values of: OverTime {'Yes', 'No'}

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
def Distribution(feature):
    ## Check the Distribution of Features in Dataset
    Features = df[feature].value_counts()
    print(f'categories of {Features}  --- \n ')
    print('**'*40)

    ## plotting

    plt.figure(figsize=(10, 6))
    sns.countplot(x=feature, data=df, order=Features.index)  ## ordered
    plt.title('CountPlot of some Features in Dataset', fontsize=14, c='k')
    plt.xlabel(feature, fontsize=14, c='k')
    plt.xticks(rotation = 45)
    plt.ylabel('Counts', fontsize=14, c='k')

    ## showing the percenatge
    for i in range(Features.shape[0]):
        count = Features[i]
        strt='{:0.2f}%'.format(100*count / df.shape[0])
        plt.text(i, count+2, strt, ha='center', color='blue', fontsize=14)

# %%
for i in Category:
    Distribution(i)
# Out:
# categories of Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64  ---
#
# ********************************************************************************
# categories of BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64  ---
#
# ********************************************************************************
# categories of Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64  ---
#
# ********************************************************************************
# categories of EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64  ---
#
# ********************************************************************************
# categories of Gender
# Male      882
# Female    588
# Name: count, dtype: int64  ---
#
# ********************************************************************************
# categories of JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64  ---
#
# ********************************************************************************
# categories of MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64  ---
#
# ********************************************************************************
# categories of Over18
# Y    1470
# Name: count, dtype: int64  ---
#
# ********************************************************************************
# categories of OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64  ---
#
# ********************************************************************************

# %%
df.hist(bins=30, figsize=(15,15))
plt.show()

# %%
fig, axes = plt.subplots(3, 4, figsize=(20, 15))
axes = axes.flatten()

# Plot each object column
for i, col in enumerate(Category):
    sns.countplot(ax=axes[i], x=col, data=df, hue='Attrition', palette=['#9a09ae', '#15ae68'], color=col)
    axes[i].set_title(f'{col}', fontdict={'font': 'Serif', 'color':  '#2E4053' , 'weight': 'bold', 'size': 16})
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')
    
    axes[i].tick_params(axis='x', rotation=45, labelsize=12)
    axes[i].tick_params(axis='y', labelsize=12)
    
    axes[i].set_facecolor('#d6d0da')

# Hide any unused axes
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

# Adjust layout
fig.patch.set_facecolor('#fcfcfc')
plt.tight_layout()
plt.savefig('plot2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
grouping=df.groupby(['Department'])[['DailyRate','EducationField','BusinessTravel']].max().sort_values(by='DailyRate',ascending=False)
grouping
# Out:
#                         DailyRate    EducationField BusinessTravel
# Department
# Sales                        1499  Technical Degree  Travel_Rarely
# Research & Development       1496  Technical Degree  Travel_Rarely
# Human Resources              1444  Technical Degree  Travel_Rarely

# %%
values_of_Department=df['Department'].value_counts()[: 10]
values_of_Department
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
mean_value=[df[df['Department']==i]['DailyRate'].mean() for i in list(values_of_Department.index)]
mean_value
# Out:
# [806.8511966701353, 800.2757847533633, 751.5396825396825]

# %%
plt.figure(figsize=(5,4))
plt.plot(values_of_Department.index, mean_value, marker='.', ms=8, mec='k', mfc='c',color='red')
plt.title('mean values of Departments', va='bottom', fontweight='heavy',fontstyle='oblique')
plt.xlabel('Departments',fontweight='heavy',fontsize=12)
plt.ylabel('mean values',fontweight='heavy',fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.bar(values_of_Department.index ,mean_value,color='#ca9c3a')
plt.xlabel('Departments',fontweight='light',fontsize=13,c='k')
plt.ylabel('mean values',fontweight='light',fontsize=13,c='k')
plt.title('mean values of Departments', va='bottom', fontweight='heavy',fontstyle='oblique')

plt.show()

# %%
plt.hist(x = df['DailyRate'], bins=60, density=True, histtype='bar',color= '#15ae68', alpha=0.7)
plt.xlabel('DailyRate',fontweight='light',fontsize=13,c='k')
plt.ylabel('distribution',fontweight='light',fontsize=13,c='k')
plt.title('distribution values of DailyRate', va='bottom', fontweight='heavy',fontstyle='oblique')

plt.show()

# %%
myexplode = [0.3, 0.2 , 0.4]
mycolors = ["#ca9c3a", "#4e6fcf", "#ca3f19"]

plt.pie(mean_value, labels= values_of_Department.index ,explode = myexplode ,colors = mycolors, startangle = 90 , autopct= '%1.1f%%' ,shadow = True)
plt.legend(title = "Names:",loc=5)
plt.show()

# %% [markdown]
# # Data preprocessing

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
object=df.select_dtypes(include='object')
non_object=df.select_dtypes(exclude='object')

# %%
le = LabelEncoder()

# %%
for i in range(0,object.shape[1]):
    object.iloc[:,i]=le.fit_transform(object.iloc[:,i])

# %%
data=pd.concat([object,non_object],axis=1)

# %%
data
# Out:
#      Attrition BusinessTravel Department EducationField Gender JobRole  \
# 0            1              2          2              1      0       7
# 1            0              1          1              1      1       6
# 2            1              2          1              4      1       2
# 3            0              1          1              1      0       6
# 4            0              2          1              3      1       2
# ...        ...            ...        ...            ...    ...     ...
# 1465         0              1          1              3      1       2
# 1466         0              2          1              3      1       0
# 1467         0              2          1              1      1       4
# 1468         0              1          2              3      1       7
# 1469         0              2          1              3      1       2
#
#      MaritalStatus Over18 OverTime  Age  ...  RelationshipSatisfaction  \
# 0                2      0        1   41  ...                         1
# 1                1      0        0   49  ...                         4
# 2                2      0        1   37  ...                         2
# 3                1      0        1   33  ...                         3
# 4                1      0        0   27  ...                         4
# ...            ...    ...      ...  ...  ...                       ...
# 1465             1      0        0   36  ...                         3
# 1466             1      0        0   39  ...                         1
# 1467             1      0        1   27  ...                         2
# 1468             1      0        0   49  ...                         4
# 1469             1      0        0   34  ...                         1
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 0                80                 0                  8
# 1                80                 1                 10
# 2                80                 0                  7
# 3                80                 0                  8
# 4                80                 1                  6
# ...             ...               ...                ...
# 1465             80                 1                 17
# 1466             80                 1                  9
# 1467             80                 1                  6
# 1468             80                 0                 17
# 1469             80                 0                  6
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                         0                1               6
# 1                         3                3              10
# 2                         3                3               0
# 3                         3                3               8
# 4                         3                3               2
# ...                     ...              ...             ...
# 1465                      3                3               5
# 1466                      5                3               7
# 1467                      0                3               6
# 1468                      3                2               9
# 1469                      3                4               4
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                      4                        0                     5
# 1                      7                        1                     7
# 2                      0                        0                     0
# 3                      7                        3                     0
# 4                      2                        2                     2
# ...                  ...                      ...                   ...
# 1465                   2                        0                     3
# 1466                   7                        1                     7
# 1467                   2                        0                     3
# 1468                   6                        0                     8
# 1469                   3                        1                     2
#
# [1470 rows x 35 columns]

# %%
sc = StandardScaler()
data['DailyRate'] = sc.fit_transform(data['DailyRate'].values.reshape(-1, 1))

# %%
data['Age'] = sc.fit_transform(data['Age'].values.reshape(-1, 1))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1470 non-null   object
#  1   BusinessTravel            1470 non-null   object
#  2   Department                1470 non-null   object
#  3   EducationField            1470 non-null   object
#  4   Gender                    1470 non-null   object
#  5   JobRole                   1470 non-null   object
#  6   MaritalStatus             1470 non-null   object
#  7   Over18                    1470 non-null   object
#  8   OverTime                  1470 non-null   object
#  9   Age                       1470 non-null   float64
#  10  DailyRate                 1470 non-null   float64
#  11  DistanceFromHome          1470 non-null   int64
#  12  Education                 1470 non-null   int64
#  13  EmployeeCount             1470 non-null   int64
#  14  EmployeeNumber            1470 non-null   int64
#  15  EnvironmentSatisfaction   1470 non-null   int64
#  16  HourlyRate                1470 non-null   int64
#  17  JobInvolvement            1470 non-null   int64
#  18  JobLevel                  1470 non-null   int64
#  19  JobSatisfaction           1470 non-null   int64
#  20  MonthlyIncome             1470 non-null   int64
#  21  MonthlyRate               1470 non-null   int64
#  22  NumCompaniesWorked        1470 non-null   int64
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: float64(2), int64(24), object(9)
# memory usage: 402.1+ KB

# %%
data['Attrition']=data['Attrition'].astype(int)
data['BusinessTravel']=data['BusinessTravel'].astype(int)
data['Department']=data['Department'].astype(int)
data['EducationField']=data['EducationField'].astype(int)
data['Gender']=data['Gender'].astype(int)
data['JobRole']=data['JobRole'].astype(int)
data['MaritalStatus']=data['MaritalStatus'].astype(int)
data['Over18']=data['Over18'].astype(int)
data['OverTime']=data['OverTime'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1470 non-null   int32
#  1   BusinessTravel            1470 non-null   int32
#  2   Department                1470 non-null   int32
#  3   EducationField            1470 non-null   int32
#  4   Gender                    1470 non-null   int32
#  5   JobRole                   1470 non-null   int32
#  6   MaritalStatus             1470 non-null   int32
#  7   Over18                    1470 non-null   int32
#  8   OverTime                  1470 non-null   int32
#  9   Age                       1470 non-null   float64
#  10  DailyRate                 1470 non-null   float64
#  11  DistanceFromHome          1470 non-null   int64
#  12  Education                 1470 non-null   int64
#  13  EmployeeCount             1470 non-null   int64
#  14  EmployeeNumber            1470 non-null   int64
#  15  EnvironmentSatisfaction   1470 non-null   int64
#  16  HourlyRate                1470 non-null   int64
#  17  JobInvolvement            1470 non-null   int64
#  18  JobLevel                  1470 non-null   int64
#  19  JobSatisfaction           1470 non-null   int64
#  20  MonthlyIncome             1470 non-null   int64
#  21  MonthlyRate               1470 non-null   int64
#  22  NumCompaniesWorked        1470 non-null   int64
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: float64(2), int32(9), int64(24)
# memory usage: 350.4 KB

# %%
data = data.drop('StandardHours', axis=1)

# %% [markdown]
# # Models and splitting data

# %%
x = data.drop('Attrition', axis=1)

y = data['Attrition']

# %%
x
# Out:
#       BusinessTravel  Department  EducationField  Gender  JobRole  \
# 0                  2           2               1       0        7
# 1                  1           1               1       1        6
# 2                  2           1               4       1        2
# 3                  1           1               1       0        6
# 4                  2           1               3       1        2
# ...              ...         ...             ...     ...      ...
# 1465               1           1               3       1        2
# 1466               2           1               3       1        0
# 1467               2           1               1       1        4
# 1468               1           2               3       1        7
# 1469               2           1               3       1        2
#
#       MaritalStatus  Over18  OverTime       Age  DailyRate  ...  \
# 0                 2       0         1  0.446350   0.742527  ...
# 1                 1       0         0  1.322365  -1.297775  ...
# 2                 2       0         1  0.008343   1.414363  ...
# 3                 1       0         1 -0.429664   1.461466  ...
# 4                 1       0         0 -1.086676  -0.524295  ...
# ...             ...     ...       ...       ...        ...  ...
# 1465              1       0         0 -0.101159   0.202082  ...
# 1466              1       0         0  0.227347  -0.469754  ...
# 1467              1       0         1 -1.086676  -1.605183  ...
# 1468              1       0         0  1.322365   0.546677  ...
# 1469              1       0         0 -0.320163  -0.432568  ...
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                     3                         1                 0
# 1                     4                         4                 1
# 2                     3                         2                 0
# 3                     3                         3                 0
# 4                     3                         4                 1
# ...                 ...                       ...               ...
# 1465                  3                         3                 1
# 1466                  3                         1                 1
# 1467                  4                         2                 1
# 1468                  3                         4                 0
# 1469                  3                         1                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 33 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int32

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.5, random_state=42)

# %% [markdown]
# # LinearRegression

# %%
linear = LinearRegression()

linear.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
linear.score(x_train, y_train)
# Out:
# 0.24728648811746134

# %%
linear.score(x_test, y_test)
# Out:
# 0.12414668886906721

# %%
y_pred = linear.predict(x_test)
y_pred
# Out:
# array([ 1.91296393e-01, -1.17486961e-01,  1.93173571e-01, -1.22187666e-01,
#         1.10913813e-01,  2.39539167e-01,  2.78493409e-01,  5.12900165e-02,
#         2.32760200e-01, -7.40179436e-02,  4.00997520e-01,  9.02042889e-02,
#         3.68567429e-01,  1.03945913e-01,  6.46851666e-02,  1.19280544e-01,
#         3.61789174e-01,  9.99193831e-02,  4.32589190e-01,  1.83348295e-01,
#         2.87484650e-01, -1.03232730e-01,  1.45517398e-01,  3.35164887e-01,
#         3.09802286e-01, -1.59589403e-02,  2.11184195e-01,  1.07659691e-02,
#         2.09815156e-01,  1.90550407e-01,  7.31434989e-02, -8.99596952e-02,
rics.mean_absolute_error(y_test, y_pred)
# Out:
# 0.247016350159122

# %%
print("Accuracy --> ",metrics.r2_score(y_test, y_pred)*100)
# Out:
# Accuracy -->  12.414668886906721

# %% [markdown]
# # DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor(max_depth=8,random_state=42)

dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, random_state=42)

# %%
print("Accuracy in train--> ",dt.score(x_train, y_train)*100)
print("Accuracy in test--> ",dt.score(x_test , y_test)*100)
# Out:
# Accuracy in train-->  83.57888861397159
# Accuracy in test-->  -52.91439279172883

# %%
y_predicte = dt.predict(x_test)
print("mean_squared_error=",metrics.mean_squared_error(y_test,y_predicte ))
print("mean_absolute_error=",metrics.mean_absolute_error(y_test, y_predicte))
# Out:
# mean_squared_error= 0.18575323453310036
# mean_absolute_error= 0.21551755983649673

# %% [markdown]
# # Random Forest Regressor

# %%
regressor = RandomForestRegressor(n_estimators=50,max_depth=10,random_state=0 ,max_samples=0.8)

regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, max_samples=0.8, n_estimators=50,
#                       random_state=0)

# %%
print("Accuracy in train--> ",regressor.score(x_train, y_train)*100)
print("Accuracy in test--> ",regressor.score(x_test , y_test)*100)
# Out:
# Accuracy in train-->  78.27654004390985
# Accuracy in test-->  16.8793689437872

# %%
y_prediction = regressor.predict(x_test)
print("mean_squared_error=",metrics.mean_squared_error(y_test, y_pred))
print("mean_absolute_error=",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# mean_squared_error= 0.10639455354649699
# mean_absolute_error= 0.247016350159122

# %%
# R Squared error
error_score = metrics.r2_score(y_test,y_pred )
print('R squared error : ', error_score *100)
# Out:
# R squared error :  12.414668886906721

# %% [markdown]
# # Gradient Boosting Regressor

# %%
GBR = GradientBoostingRegressor(n_estimators=200, max_depth=7)

# %%
gbr = GBR.fit(x_train, y_train)

# %%
print("Accuracy in train--> ",gbr.score(x_train, y_train)*100)
print("Accuracy in test--> ",gbr.score(x_test, y_test)*100)
# Out:
# Accuracy in train-->  99.99967011569564
# Accuracy in test-->  -5.062673607549084

# %%
y_pred= gbr.predict((x_test))

# %%
print("mean_squared_error=",metrics.mean_squared_error(y_test, y_pred))
print("mean_absolute_error=",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# mean_squared_error= 0.1276252097333852
# mean_absolute_error= 0.21407981011539143

# %%
error_score = metrics.r2_score(y_test, y_pred ) # coefficient of determination, regression score function.
print('R squared error : ', error_score *100)
# Out:
# R squared error :  -5.062673607549084

# %% [markdown]
# ## KNeighborsRegressor

# %%
model1 = KNeighborsRegressor(n_neighbors=4 )

model1.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
print("Accuracy in train--> ",model1.score(x_train, y_train)*100)
print("Accuracy in test--> ",model1.score(x_test, y_test)*100)
# Out:
# Accuracy in train-->  32.2406670746634
# Accuracy in test-->  -26.84193282945264

# %%
y_pred = model1.predict(x_test)
print("mean_squared_error=",metrics.mean_squared_error(y_test, y_pred))
print("mean_absolute_error=",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# mean_squared_error= 0.1540816326530612
# mean_absolute_error= 0.2537414965986395

# %% [markdown]
# # SVR

# %%
svr = SVR(kernel = 'rbf')
svr.fit(x_train, y_train)
# Out:
# SVR()

# %%
y_pred = svr.predict(x_test)
